# %%
import json

# %%
nw = {}

# %%
with open('public/german_english.json') as f:
    d = json.load(f)
    nw = {a.lower() : b for a, b in d.items()}

# %%
nw
# Out:
# {'abbiegen': 'turn',
#  'abend': 'evening',
#  'abendessen': 'dinner',
#  'abendkleidung': 'evening dress',
#  'abenteuer': 'adventure',
#  'aber': 'but',
#  'abfahren': 'leave (irr.)',
#  'abfall': 'waste',
#  'abfliegen': 'start',
#  'abgabe': 'tax',
#  'abgehoben': 'withdrawn',
#  'abgenutzt': 'worn-out',
#  'abgeordneter': 'representative',
#  'abgrenzung': 'boundary',
#  'abhang': 'slope',
#  'abhängen': 'depend',
#  'abhängig': 'dependent',
#  'abhängigkeit': 'dependence',
#  'abhängig sein von': 'depend on',
#  'abhärten': 'harden',
#  'abheben (geld)': 'withdraw (irr.)',
#  'abklären': 'clear',
#  'abkühlen': 'cool',
#  'ablehnen': 'refuse',
#  'ablehnung': 'refusal',
#  'abmachung': 'arrangement',
#  'abnahme': 'lessening',
#  'abnehmen': 'decrease',
#  'abnehmen (hut)': 'take off',
#  'abnutzen': 'wear down',
#  'abnutzung': 'wear',
#  'abrechnung': 'account',
#  'abreise': 'departure',
#  'abreisen': 'start',
#  'abreisen nach': 'leave for',
#  'absatz': 'heel',
# ...

# %%
with open('public/german_english.json', 'w') as f:
    json.dump(nw, f)
